# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhil1610/scraper/blob/main/Long_Desc_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Welcome to Colab!</h1>
#
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <h1>What is Colab?</h1>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# ## **Getting started**
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# ## Data science
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# ## Machine learning
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# ## More Resources
#
# ### Working with Notebooks in Colab
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [TensorFlow 2 in Colab](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import json

# %%
with open("/content/TOI_Chandni_Chowk_Cases.json") as file:
  data =json.load(file)

# %%
print(data)
# Out:
# {'data': [{'id': 1, 'title': ' Pune: Passengers’ harassment by auto drivers continues ', 'description': ' The Pune railway station bustled on Wednesday morning with passengers either rushing to board trains or dozing in various parts of the facility waiting for their journeys to start. ', 'date': ' Sep 16, 2021, 04:53 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/pune/passengers-harassment-by-auto-drivers-continues/articleshow/86244487.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 2, 'title': ' 2020 assembly polls will give another Sheila Dikshit to Delhi: Alka Lamba ', 'description': '  ', 'date': ' Jan 24, 2020, 19:01 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/delhi/2020-assembly-polls-will-give-another-sheila-dikshit-to-delhi-alka-lamba/articleshow/73587203.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 3, 'title': ' Scottish historian reflects on horrors of 1857 uprising ', 'description': ' undefined ', 'date': ' Dec 09, 2017, 07:30 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/chandigarh/scottish-historian-reflects-on-horrors-of-1857-uprising/articleshow/61990784.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 4, 'title': ' Porn racket stink in rape of two teens ', 'description': ' A Chandni Chowk trader was arrested in the wee hours of Friday for allegedly raping two 16-year-old girls in a warehouse in Taltala ', 'date': ' Mar 14, 2015, 00:34 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/kolkata/porn-racket-stink-in-rape-of-two-teens/articleshow/46559354.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 5, 'title': ' Tisca Chopra: In Delhi, people have a lot more time for living ', 'description': ' As a student of Hindu College, Tisca Chopra spent many years in Delhi and observed, that unlike other metro cities, \'a lot of living happens in Delhi and it is not just that everyone is busy in their own world." ', 'date': ' Oct 11, 2016, 01:00 (IST)', 'link': 'https://timesofindia.indiatimes.com/entertainment/hindi/bollywood/news/tisca-chopra-in-delhi-people-have-a-lot-more-time-for-living/articleshow/54782231.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 6, 'title': " Estate agent abducts 'wife stalker', held ", 'description': " The Warje police on Wednesday arrested a 34-year-old estate agent from Shivane for abducting and beating up a tour operator near Chandni Chowk late on Tuesday night.The tour operator allegedly stalked the agent's wife. ", 'date': ' Sep 30, 2016, 07:17 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/pune/estate-agent-abducts-wife-stalker-held/articleshow/54595780.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 7, 'title': ' Business’s stalkers held; planned to rob him ', 'description': ' Four people who were about to rob a Chandni Chowk businessman were arrested on Wednesday. ', 'date': ' Jun 27, 2013, 01:25 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/delhi/businesss-stalkers-held-planned-to-rob-him/articleshow/20787659.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 8, 'title': ' Delhi assembly resolves to make rape of minor punishable by death ', 'description': '  ', 'date': ' Mar 28, 2018, 01:06 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/delhi/assembly-resolves-to-make-rape-of-minor-punishable-by-death/articleshow/63494686.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 9, 'title': ' Man held for sexual assault on minor girl ', 'description': '  ', 'date': ' Nov 22, 2018, 04:48 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/ghaziabad/man-45-held-for-sexual-assault-on-minor-girl/articleshow/66742281.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 10, 'title': ' Man held for Gurugram rape-murder may have struck 8 times earlier ', 'description': " 20-year-old Sunil is being termed as the worst paedophile-serial killers known to Indian law enforcement agencies, respo ...

# %%
links = data['data']
print(links)
# Out:
# [{'id': 1, 'title': ' Pune: Passengers’ harassment by auto drivers continues ', 'description': ' The Pune railway station bustled on Wednesday morning with passengers either rushing to board trains or dozing in various parts of the facility waiting for their journeys to start. ', 'date': ' Sep 16, 2021, 04:53 (IST)', 'link': 'https://timesofindia.indiatimes.com/city/pune/passengers-harassment-by-auto-drivers-continues/articleshow/86244487.cms', 'location': 'Chandni Chowk', 'category': 'Rape'}, {'id': 2, 'title': ' 2020 assembly polls will give another Sheila Dikshit to Delhi: Alka Lamba ', 'description': '  ', 'date': ' Jan 24, 2020, 19:01 (IST)', 'link': 'https://timesofindia.indiatimes.com/city
have-struck-8-times-earlier/articleshow/66716226.cms', 'https://timesofindia.indiatimes.com/city/delhi/nearly-half-of-rape-cases-in-delhi-have-kids-as-victims-most-in-outer-district/articleshow/61773745.cms', 'https://timesofindia.indiatimes.com/city/kolkata/rape-chargesheet-filed-in-24-days/articleshow/46830356.cms', 'https://timesofindia.indiatimes.com/city/gurgaon/businessman-booked-for-rape-at-hotel/articleshow/42654942.cms', 'https://timesofindia.indiatimes.com/city/pune/four-arrested-for-raping-23-year-old-in-a-moving-car/articleshow/51901808.cms', 'https://timesofindia.indiatimes.com/entertainment/hindi/theatre/martin-moran-the-idea-that-rape-is-something-inevitable-is-beyond-comprehension/articleshow/45258993.cms', 'https://timesofindia.indiatimes.com/city/jaipur/7-year-old-raped-by-ragpicker/articleshow/12816792.cms', 'https://timesofindia.indiatimes.com/city/jaipur/police-nabs-accused-in-7-yr-old-rape-case/articleshow/12829744.cms', 'https://timesofindia.indiatimes.com/city/kolkata/trader-arrested-on-charge-of-raping-domestic-help/articleshow/6126010.cms', 'https://timesofindia.indiatimes.com/city/delhi/life-for-man-who-raped-killed-daughter/articleshow/5301742.cms', 'https://timesofindia.indiatimes.com/city/patna/minor-raped-by-doctors-corporator/articleshow/2883916.cms', 'https://timesofindia.indiatimes.com/city/patna/docs-corporator-rape-10-yr-old/articleshow/2886234.cms', 'https://timesofindia.indiatimes.com/city/delhi/child-murder-servant-admits-to-rape-as-well/articleshow/2220284.cms', 'https://timesofindia.indiatimes.com/india/could-these-bollywood-films-have-been-made-today/articleshow/87333452.cms', 'https://timesofindia.indiatimes.com/city/pune/law-student-held-on-charge-of-outraging-modesty-of-college-friend/articleshow/73709942.cms', 'https://timesofindia.indiatimes.com/city/patna/section-144-clamped-in-mohania-after-2-sustain-gunshot-injuries/articleshow/72283302.cms', 'https://timesofindia.indiatimes.com/city/gurgaon/sit-takes-serial-rapist-killer-to-gwalior-digs-up-bones-of-girl-murdered-in-2013/articleshow/66790512.cms', 'https://timesofindia.indiatimes.com/city/gurgaon/skeleton-of-4-yr-old-girl-found-in-gwalior-second-victim-in-city-linked-to-serial-killer/articleshow/66818527.cms', 'https://timesofindia.indiatimes.com/city/delhi/aap-members-to-meet-top-cop-over-threats-to-du-student/articleshow/57381353.cms', 'https://timesofindia.indiatimes.com/india/cops-question-asia-pacific-head-of-cab-company/articleshow/45465201.cms', 'https://timesofindia.indiatimes.com/city/delhi/permission-for-every-location-in-delhi-makes-shoot-hectic-for-films-crew/articleshow/54611717.cms', 'https://timesofindia.indiatimes.com/city/jaipur/7-year-old-raped-by-ragpicker/articleshow/1281 ...

# %%
len(urls)
# Out:
# 349

# %%
from bs4 import BeautifulSoup
import requests
import pprint
import re

# %%
class article:
  def __init__(self,id,description):
    self.id=id
    self.description=description

# %%
long_descriptions =[]
id=1
for url in urls:
  response = requests.get(url)
  soup = BeautifulSoup(response.content, "html.parser")
  description=''

  #print titles only
  # texts = soup.find_all(attrs={"data-articlebody":"1"})
  # texts = soup.find_all(class_="clearfix")

  for ele in soup.select('div[class*="fewcent"]'):
    description+=ele.get_text();
  # print(texts)
  # for i in range(5,11):
  #   print(texts[i].get_text());
  #   description+=texts[i].get_text()

  long_descriptions.append(article(id,description))
  id+=1

# long_descriptions.append({description})

# %%
len(long_descriptions)
# Out:
# 349

# %%
import csv
with open('Chandni_Chowk.csv', 'w',) as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Id', 'Long_Description'])
    for article in long_descriptions:
        writer.writerow([article.id, article.description])
